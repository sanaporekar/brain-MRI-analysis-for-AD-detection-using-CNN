# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import skimage.io
import os
import tqdm
import glob
import tensorflow

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import gray2rgb
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.utils import to_categorical
from keras import optimizers

from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout

import keras.backend as K

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2,

        rotation_range=5,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        #zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                  validation_split = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255
                                  )

# %%
train_dataset  = train_datagen.flow_from_directory(directory = '/content/drive/MyDrive/AD-CN/AD-CN/train',
                                                   target_size = (224,224),
                                                   class_mode = 'binary',
                                                   subset = 'training',
                                                   batch_size = 32)
# Out:
# Found 867 images belonging to 2 classes.

# %%
valid_dataset = valid_datagen.flow_from_directory(directory = '/content/drive/MyDrive/AD-CN/AD-CN/train',
                                                  target_size = (224,224),
                                                  class_mode = 'binary',
                                                  subset = 'validation',
                                                  batch_size = 32)
# Out:
# Found 216 images belonging to 2 classes.

# %%
test_dataset = test_datagen.flow_from_directory(directory = '/content/drive/MyDrive/AD-CN/AD-CN/test',
                                                  target_size = (224,224),
                                                  class_mode = 'binary',
                                                  batch_size = 32)
# Out:
# Found 323 images belonging to 2 classes.

# %%
base_model = ResNet50(input_shape=(224,224,3),
                   include_top=False,
                   weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step

# %%
# Freezing Layers

for layer in base_model.layers:
    layer.trainable=False

# %%
# Building Model

model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('tanh'))
model.add(Dense(1,activation='sigmoid'))

# %%
# Model Summary

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  dropout (Dropout)           (None, 7, 7, 2048)        0
#
#  flatten (Flatten)           (None, 100352)            0
#
#  batch_normalization (Batch  (None, 100352)            401408
#  Normalization)
#
#  dense (Dense)               (None, 64)                6422592
#
#  batch_normalization_1 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation (Activation)     (None, 64)                0
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  batch_normalization_2 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_1 (Activation)   (None, 64)                0
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  batch_normalization_3 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_2 (Activation)   (None, 64)                0
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  batch_normalization_4 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_3 (Activation)   (None, 32)                0
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  batch_normalization_5 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_4 (Activation)   (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 30424225 (116.06 MB)
# Trainable params: 6635297 (25.31 MB)
# Non-trainable params: 23788928 (90.75 MB)
# _________________________________________________________________

# %%
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 5) # when i run it for 50 epochs

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy',metrics=METRICS)

# %%
history=model.fit(train_dataset,
                        validation_data=valid_dataset,
                        epochs = 20,
                        verbose = 1,
                         callbacks=lr_scheduler)
# Out:
# Epoch 1/20
# 28/28 [==============================] - 239s 8s/step - loss: 0.6845 - accuracy: 0.5825 - precision: 0.5208 - recall: 0.4987 - auc: 0.6132 - f1_score: 0.5195 - val_loss: 0.9375 - val_accuracy: 0.5694 - val_precision: 1.0000 - val_recall: 0.0106 - val_auc: 0.7842 - val_f1_score: 0.0220 - lr: 0.0100
# Epoch 2/20
# 28/28 [==============================] - 16s 573ms/step - loss: 0.5790 - accuracy: 0.7047 - precision: 0.6631 - recall: 0.6525 - auc: 0.7629 - f1_score: 0.6574 - val_loss: 0.6542 - val_accuracy: 0.5694 - val_precision: 0.5200 - val_recall: 0.1383 - val_auc: 0.8180 - val_f1_score: 0.1830 - lr: 0.0063
# Epoch 3/20
# 28/28 [==============================] - 16s 566ms/step - loss: 0.5292 - accuracy: 0.7589 - precision: 0.7258 - recall: 0.7162 - auc: 0.8091 - f1_score: 0.6915 - val_loss: 0.6217 - val_accuracy: 0.6991 - val_precision: 0.6986 - val_recall: 0.5426 - val_auc: 0.8198 - val_f1_score: 0.6014 - lr: 0.0040
# Epoch 4/20
# 28/28 [==============================] - 16s 579ms/step - loss: 0.5259 - accuracy: 0.7451 - precision: 0.6960 - recall: 0.7347 - auc: 0.8110 - f1_score: 0.7114 - val_loss: 0.5884 - val_accuracy: 0.7083 - val_precision: 0.7067 - val_recall: 0.5638 - val_auc: 0.8354 - val_f1_score: 0.6174 - lr: 0.0025
# Epoch 5/20
# 28/28 [==============================] - 16s 560ms/step - loss: 0.5124 - accuracy: 0.7693 - precision: 0.7299 - recall: 0.7454 - auc: 0.8198 - f1_score: 0.7311 - val_loss: 0.5664 - val_accuracy: 0.7593 - val_precision: 0.7386 - val_recall: 0.6915 - val_auc: 0.8420 - val_f1_score: 0.7171 - lr: 0.0016
# Epoch 6/20
# 28/28 [==============================] - 16s 559ms/step - loss: 0.4909 - accuracy: 0.7832 - precision: 0.7392 - recall: 0.7745 - auc: 0.8347 - f1_score: 0.7524 - val_loss: 0.5143 - val_accuracy: 0.7778 - val_precision: 0.7347 - val_recall: 0.7660 - val_auc: 0.8490 - val_f1_score: 0.7434 - lr: 0.0010
# Epoch 7/20
# 28/28 [==============================] - 16s 556ms/step - loss: 0.4601 - accuracy: 0.8028 - precision: 0.7668 - recall: 0.7851 - auc: 0.8592 - f1_score: 0.7654 - val_loss: 0.5472 - val_accuracy: 0.7685 - val_precision: 0.7292 - val_recall: 0.7447 - val_auc: 0.8529 - val_f1_score: 0.7383 - lr: 6.3096e-04
# Epoch 8/20
# 28/28 [==============================] - 16s 556ms/step - loss: 0.5087 - accuracy: 0.7705 - precision: 0.7225 - recall: 0.7666 - auc: 0.8258 - f1_score: 0.7386 - val_loss: 0.5246 - val_accuracy: 0.7778 - val_precision: 0.7300 - val_recall: 0.7766 - val_auc: 0.8542 - val_f1_score: 0.7598 - lr: 3.9811e-04
# Epoch 9/20
# 28/28 [==============================] - 16s 555ms/step - loss: 0.4964 - accuracy: 0.7762 - precision: 0.7215 - recall: 0.7905 - auc: 0.8335 - f1_score: 0.7476 - val_loss: 0.5186 - val_accuracy: 0.7731 - val_precision: 0.7228 - val_recall: 0.7766 - val_auc: 0.8538 - val_f1_score: 0.7308 - lr: 2.5119e-04
# Epoch 10/20
# 28/28 [==============================] - 15s 545ms/step - loss: 0.4602 - accuracy: 0.7797 - precision: 0.7302 - recall: 0.7825 - auc: 0.8607 - f1_score: 0.7592 - val_loss: 0.5117 - val_accuracy: 0.7778 - val_precision: 0.7212 - val_recall: 0.7979 - val_auc: 0.8577 - val_f1_score: 0.7491 - lr: 1.5849e-04
# Epoch 11/20
# 28/28 [==============================] - 16s 555ms/step - loss: 0.4842 - accuracy: 0.7797 - precision: 0.7279 - recall: 0.7878 - auc: 0.8452 - f1_score: 0.7425 - val_loss: 0.5081 - val_accuracy: 0.7778 - val_precision: 0.7212 - val_recall: 0.7979 - val_auc: 0.8579 - val_f1_score: 0.7379 - lr: 1.0000e-04
# Epoch 12/20
# 28/28 [==============================] - 16s 557ms/step - loss: 0.5222 - accuracy: 0.7566 - precision: 0.7075 - recall: 0.7507 - auc: 0.8170 - f1_score: 0.7210 - val_loss: 0.5065 - val_accuracy: 0.7731 - val_precision: 0.7143 - val_recall: 0.7979 - val_auc: 0.8593 - val_f1_score: 0.7359 - lr: 6.3096e-05
# Epoch 13/20
# 28/28 [==============================] - 15s 551ms/step - loss: 0.4742 - accuracy: 0.7889 - precision: 0.7449 - recall: 0.7825 - auc: 0.8490 - f1_score: 0.7587 - val_loss: 0.5070 - val_accuracy: 0.7731 - val_precision: 0.7143 - val_recall: 0.7979 - val_auc: 0.8599 - val_f1_score: 0.7425 - lr: 3.9811e-05
# Epoch 14/20
# 28/28 [==============================] - 16s 568ms/step - loss: 0.4815 - accuracy: 0.7705 - precision: 0.7214 - recall: 0.7692 - auc: 0.8478 - f1_score: 0.7198 - val_loss: 0.5080 - val_accuracy: 0.7731 - val_precision: 0.7103 - val_recall: 0.8085 - val_auc: 0.8601 - val_f1_score: 0.7544 - lr: 2.5119e-05
# Epoch 15/20
# 28/28 [==============================] - 17s 578ms/step - loss: 0.5001 - accuracy: 0.7705 - precision: 0.7247 - recall: 0.7613 - auc: 0.8305 - f1_score: 0.7332 - val_loss: 0.5076 - val_accuracy: 0.7778 - val_precision: 0.7170 - val_recall: 0.8085 - val_auc: 0.8607 - val_f1_score: 0.7548 - lr: 1.5849e-05
# Epoch 16/20
# 28/28 [==============================] - 16s 574ms/step - loss: 0.4915 - accuracy: 0.7832 - precision: 0.7357 - recall: 0.7825 - auc: 0.8353 - f1_score: 0.7528 - val_loss: 0.5084 - val_accuracy: 0.7731 - val_precision: 0.7103 - val_recall: 0.8085 - val_auc: 0.8608 - val_f1_score: 0.7530 - lr: 1.0000e-05
# Epoch 17/20
# 28/28 [==============================] - 16s 567ms/step - loss: 0.5040 - accuracy: 0.7601 - precision: 0.7086 - recall: 0.7613 - auc: 0.8290 - f1_score: 0.7277 - val_loss: 0.5063 - val_accuracy: 0.7639 - val_precision: 0.6972 - val_recall: 0.8085 - val_auc: 0.8620 - val_f1_score: 0.7402 - lr: 6.3096e-06
# Epoch 18/20
# 28/28 [==============================] - 17s 624ms/step - loss: 0.5245 - accuracy: 0.7509 - precision: 0.7069 - recall: 0.7294 - auc: 0.8145 - f1_score: 0.6876 - val_loss: 0.5055 - val_accuracy: 0.7639 - val_precision: 0.6972 - val_recall: 0.8085 - val_auc: 0.8618 - val_f1_score: 0.7488 - lr: 3.9811e-06
# Epoch 19/20
# 28/28 [==============================] - 16s 560ms/step - loss: 0.4783 - accuracy: 0.8028 - precision: 0.7550 - recall: 0.8090 - auc: 0.8434 - f1_score: 0.7759 - val_loss: 0.5047 - val_accuracy: 0.7639 - val_precision: 0.6972 - val_recall: 0.8085 - val_auc: 0.8633 - val_f1_score: 0.7378 - lr: 2.5119e-06
# Epoch 20/20
# 28/28 [==============================] - 16s 558ms/step - loss: 0.5014 - accuracy: 0.7659 - precision: 0.7143 - recall: 0.7692 - auc: 0.8308 - f1_score: 0.7272 - val_loss: 0.5042 - val_accuracy: 0.7639 - val_precision: 0.6903 - val_recall: 0.8298 - val_auc: 0.8638 - val_f1_score: 0.7350 - lr: 1.5849e-06

# %%
#%% PLOTTING RESULTS (Train vs Validation FOLDER 1)

def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1,val_f1):

    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])

    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])

    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()


Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision'],
               history.history['f1_score'],history.history['val_f1_score']
              )

# %%
scores = model.evaluate(test_dataset)
# Out:
# 11/11 [==============================] - 102s 10s/step - loss: 0.4593 - accuracy: 0.7895 - precision: 0.7436 - recall: 0.8896 - auc: 0.8814 - f1_score: 0.8091

# %%
print("Accuracy = ", scores[1])
print("Precision = ", scores[2])
print("Recall = ", scores[3])
print("AUC = ", scores[4])
print("F1_score = ", scores[5])
# Out:
# Accuracy =  0.7894737124443054
# Precision =  0.7435897588729858
# Recall =  0.8895705342292786
# AUC =  0.8814417123794556
# F1_score =  0.8091369867324829
