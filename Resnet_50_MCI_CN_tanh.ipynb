# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import skimage.io
import os
import tqdm
import glob
import tensorflow

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import gray2rgb
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.utils import to_categorical
from keras import optimizers

from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
import keras.backend as K

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2,

        rotation_range=5,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        #zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                  validation_split = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255
                                  )

# %%
train_dataset  = train_datagen.flow_from_directory(directory = '/content/drive/MyDrive/MCI-CN/MCI-CN/train',
                                                   target_size = (224,224),
                                                   class_mode = 'binary',
                                                   subset = 'training',
                                                   batch_size = 32)
# Out:
# Found 858 images belonging to 2 classes.

# %%
valid_dataset = valid_datagen.flow_from_directory(directory = '/content/drive/MyDrive/MCI-CN/MCI-CN/train',
                                                  target_size = (224,224),
                                                  class_mode = 'binary',
                                                  subset = 'validation',
                                                  batch_size = 32)
# Out:
# Found 214 images belonging to 2 classes.

# %%
test_dataset = test_datagen.flow_from_directory(directory = '/content/drive/MyDrive/MCI-CN/MCI-CN/test',
                                                  target_size = (224,224),
                                                  class_mode = 'binary',
                                                  batch_size = 32)
# Out:
# Found 286 images belonging to 2 classes.

# %%
base_model = ResNet50(input_shape=(224,224,3),
                   include_top=False,
                   weights="imagenet")

# %%
# Freezing Layers

for layer in base_model.layers:
    layer.trainable=False

# %%
# Building Model

model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('tanh'))
model.add(Dense(1,activation='sigmoid'))

# %%
# Model Summary

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  dropout_10 (Dropout)        (None, 7, 7, 2048)        0
#
#  flatten_2 (Flatten)         (None, 100352)            0
#
#  batch_normalization_12 (Ba  (None, 100352)            401408
#  tchNormalization)
#
#  dense_12 (Dense)            (None, 64)                6422592
#
#  batch_normalization_13 (Ba  (None, 64)                256
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 64)                0
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_13 (Dense)            (None, 64)                4160
#
#  batch_normalization_14 (Ba  (None, 64)                256
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 64)                0
#
#  dropout_12 (Dropout)        (None, 64)                0
#
#  dense_14 (Dense)            (None, 64)                4160
#
#  batch_normalization_15 (Ba  (None, 64)                256
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 64)                0
#
#  dropout_13 (Dropout)        (None, 64)                0
#
#  dense_15 (Dense)            (None, 32)                2080
#
#  batch_normalization_16 (Ba  (None, 32)                128
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 32)                0
#
#  dropout_14 (Dropout)        (None, 32)                0
#
#  dense_16 (Dense)            (None, 32)                1056
#
#  batch_normalization_17 (Ba  (None, 32)                128
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 32)                0
#
#  dense_17 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 30424225 (116.06 MB)
# Trainable params: 6635297 (25.31 MB)
# Non-trainable params: 23788928 (90.75 MB)
# _________________________________________________________________

# %%
def f1_score(y_true, y_pred): 
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 5) # when i run it for 50 epochs

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy',metrics=METRICS)

# %%
history=model.fit(train_dataset,
                        validation_data=valid_dataset,
                        epochs = 20,
                        verbose = 1,
                         callbacks=lr_scheduler)
# Out:
# Epoch 1/20
# 27/27 [==============================] - 22s 581ms/step - loss: 0.6544 - accuracy: 0.6200 - precision: 0.6638 - recall: 0.6528 - auc: 0.6592 - f1_score: 0.6517 - val_loss: 0.7485 - val_accuracy: 0.5888 - val_precision: 0.5825 - val_recall: 0.9417 - val_auc: 0.7960 - val_f1_score: 0.7234 - lr: 0.0100
# Epoch 2/20
# 27/27 [==============================] - 15s 543ms/step - loss: 0.5331 - accuracy: 0.7541 - precision: 0.7812 - recall: 0.7796 - auc: 0.8048 - f1_score: 0.7793 - val_loss: 0.6919 - val_accuracy: 0.7056 - val_precision: 0.9524 - val_recall: 0.5000 - val_auc: 0.8657 - val_f1_score: 0.6514 - lr: 0.0063
# Epoch 3/20
# 27/27 [==============================] - 15s 544ms/step - loss: 0.4916 - accuracy: 0.7914 - precision: 0.8297 - recall: 0.7900 - auc: 0.8376 - f1_score: 0.8067 - val_loss: 0.5198 - val_accuracy: 0.7850 - val_precision: 0.8491 - val_recall: 0.7500 - val_auc: 0.8584 - val_f1_score: 0.8003 - lr: 0.0040
# Epoch 4/20
# 27/27 [==============================] - 15s 539ms/step - loss: 0.4927 - accuracy: 0.7739 - precision: 0.8126 - recall: 0.7755 - auc: 0.8403 - f1_score: 0.7908 - val_loss: 0.5209 - val_accuracy: 0.7804 - val_precision: 0.8174 - val_recall: 0.7833 - val_auc: 0.8548 - val_f1_score: 0.7971 - lr: 0.0025
# Epoch 5/20
# 27/27 [==============================] - 15s 544ms/step - loss: 0.4867 - accuracy: 0.7855 - precision: 0.8235 - recall: 0.7859 - auc: 0.8384 - f1_score: 0.8029 - val_loss: 0.5207 - val_accuracy: 0.7897 - val_precision: 0.8866 - val_recall: 0.7167 - val_auc: 0.8645 - val_f1_score: 0.7984 - lr: 0.0016
# Epoch 6/20
# 27/27 [==============================] - 15s 549ms/step - loss: 0.4849 - accuracy: 0.7681 - precision: 0.8079 - recall: 0.7692 - auc: 0.8431 - f1_score: 0.7866 - val_loss: 0.5019 - val_accuracy: 0.7944 - val_precision: 0.8725 - val_recall: 0.7417 - val_auc: 0.8610 - val_f1_score: 0.7984 - lr: 0.0010
# Epoch 7/20
# 27/27 [==============================] - 15s 548ms/step - loss: 0.4509 - accuracy: 0.7949 - precision: 0.8381 - recall: 0.7859 - auc: 0.8689 - f1_score: 0.8102 - val_loss: 0.5141 - val_accuracy: 0.7757 - val_precision: 0.8830 - val_recall: 0.6917 - val_auc: 0.8638 - val_f1_score: 0.7714 - lr: 6.3096e-04
# Epoch 8/20
# 27/27 [==============================] - 15s 543ms/step - loss: 0.4625 - accuracy: 0.7925 - precision: 0.8301 - recall: 0.7921 - auc: 0.8592 - f1_score: 0.8112 - val_loss: 0.5152 - val_accuracy: 0.7944 - val_precision: 0.9222 - val_recall: 0.6917 - val_auc: 0.8668 - val_f1_score: 0.7923 - lr: 3.9811e-04
# Epoch 9/20
# 27/27 [==============================] - 15s 550ms/step - loss: 0.4841 - accuracy: 0.7844 - precision: 0.8304 - recall: 0.7734 - auc: 0.8411 - f1_score: 0.7993 - val_loss: 0.5125 - val_accuracy: 0.7944 - val_precision: 0.9222 - val_recall: 0.6917 - val_auc: 0.8693 - val_f1_score: 0.7694 - lr: 2.5119e-04
# Epoch 10/20
# 27/27 [==============================] - 15s 539ms/step - loss: 0.4627 - accuracy: 0.7902 - precision: 0.8308 - recall: 0.7859 - auc: 0.8590 - f1_score: 0.8065 - val_loss: 0.5210 - val_accuracy: 0.7897 - val_precision: 0.9213 - val_recall: 0.6833 - val_auc: 0.8658 - val_f1_score: 0.7777 - lr: 1.5849e-04
# Epoch 11/20
# 27/27 [==============================] - 15s 544ms/step - loss: 0.4634 - accuracy: 0.8077 - precision: 0.8511 - recall: 0.7963 - auc: 0.8490 - f1_score: 0.8210 - val_loss: 0.5302 - val_accuracy: 0.7850 - val_precision: 0.9205 - val_recall: 0.6750 - val_auc: 0.8678 - val_f1_score: 0.7826 - lr: 1.0000e-04
# Epoch 12/20
# 27/27 [==============================] - 15s 556ms/step - loss: 0.4643 - accuracy: 0.7914 - precision: 0.8326 - recall: 0.7859 - auc: 0.8550 - f1_score: 0.8079 - val_loss: 0.5409 - val_accuracy: 0.7710 - val_precision: 0.9176 - val_recall: 0.6500 - val_auc: 0.8671 - val_f1_score: 0.7623 - lr: 6.3096e-05
# Epoch 13/20
# 27/27 [==============================] - 15s 551ms/step - loss: 0.4707 - accuracy: 0.7844 - precision: 0.8260 - recall: 0.7796 - auc: 0.8536 - f1_score: 0.8006 - val_loss: 0.5508 - val_accuracy: 0.7664 - val_precision: 0.9167 - val_recall: 0.6417 - val_auc: 0.8653 - val_f1_score: 0.7115 - lr: 3.9811e-05
# Epoch 14/20
# 27/27 [==============================] - 15s 556ms/step - loss: 0.4579 - accuracy: 0.7972 - precision: 0.8434 - recall: 0.7838 - auc: 0.8625 - f1_score: 0.8125 - val_loss: 0.5581 - val_accuracy: 0.7617 - val_precision: 0.9259 - val_recall: 0.6250 - val_auc: 0.8676 - val_f1_score: 0.7427 - lr: 2.5119e-05
# Epoch 15/20
# 27/27 [==============================] - 15s 549ms/step - loss: 0.4594 - accuracy: 0.8030 - precision: 0.8467 - recall: 0.7921 - auc: 0.8599 - f1_score: 0.8190 - val_loss: 0.5672 - val_accuracy: 0.7617 - val_precision: 0.9367 - val_recall: 0.6167 - val_auc: 0.8669 - val_f1_score: 0.7381 - lr: 1.5849e-05
# Epoch 16/20
# 27/27 [==============================] - 15s 559ms/step - loss: 0.4624 - accuracy: 0.7937 - precision: 0.8393 - recall: 0.7817 - auc: 0.8564 - f1_score: 0.8081 - val_loss: 0.5771 - val_accuracy: 0.7523 - val_precision: 0.9351 - val_recall: 0.6000 - val_auc: 0.8664 - val_f1_score: 0.7272 - lr: 1.0000e-05
# Epoch 17/20
# 27/27 [==============================] - 15s 562ms/step - loss: 0.4683 - accuracy: 0.7960 - precision: 0.8430 - recall: 0.7817 - auc: 0.8543 - f1_score: 0.8098 - val_loss: 0.5819 - val_accuracy: 0.7523 - val_precision: 0.9351 - val_recall: 0.6000 - val_auc: 0.8641 - val_f1_score: 0.7301 - lr: 6.3096e-06
# Epoch 18/20
# 27/27 [==============================] - 15s 547ms/step - loss: 0.4695 - accuracy: 0.7937 - precision: 0.8363 - recall: 0.7859 - auc: 0.8485 - f1_score: 0.8088 - val_loss: 0.5843 - val_accuracy: 0.7523 - val_precision: 0.9351 - val_recall: 0.6000 - val_auc: 0.8725 - val_f1_score: 0.7261 - lr: 3.9811e-06
# Epoch 19/20
# 27/27 [==============================] - 15s 554ms/step - loss: 0.4755 - accuracy: 0.7949 - precision: 0.8427 - recall: 0.7796 - auc: 0.8470 - f1_score: 0.8121 - val_loss: 0.5949 - val_accuracy: 0.7477 - val_precision: 0.9342 - val_recall: 0.5917 - val_auc: 0.8690 - val_f1_score: 0.7089 - lr: 2.5119e-06
# Epoch 20/20
# 27/27 [==============================] - 15s 546ms/step - loss: 0.4712 - accuracy: 0.7890 - precision: 0.8289 - recall: 0.7859 - auc: 0.8543 - f1_score: 0.8048 - val_loss: 0.6006 - val_accuracy: 0.7477 - val_precision: 0.9342 - val_recall: 0.5917 - val_auc: 0.8691 - val_f1_score: 0.7192 - lr: 1.5849e-06

# %%
#%% PLOTTING RESULTS (Train vs Validation FOLDER 1)

def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1,val_f1):

    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])

    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])

    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()


Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision'],
               history.history['f1_score'],history.history['val_f1_score']
              )

# %%
scores = model.evaluate(test_dataset)
# Out:
# 9/9 [==============================] - 2s 167ms/step - loss: 0.2400 - accuracy: 0.9196 - precision: 0.9717 - recall: 0.8374 - auc: 0.9682 - f1_score: 0.8929

# %%
print("Accuracy = ", scores[1])
print("Precision = ", scores[2])
print("Recall = ", scores[3])
print("AUC = ", scores[4])
print("F1_score = ", scores[5])
# Out:
# Accuracy =  0.9195803999900818
# Precision =  0.9716981053352356
# Recall =  0.8373983502388
# AUC =  0.9682028293609619
# F1_score =  0.8928858637809753
