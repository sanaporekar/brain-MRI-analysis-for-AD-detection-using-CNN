# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import skimage.io
import os
import tqdm
import glob
import tensorflow

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import gray2rgb

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import DenseNet121 

from keras import optimizers

from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
import keras.backend as K

from typing import Optional

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2,

        rotation_range=5,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                  validation_split = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255
                                  )

# %%
train_dataset  = train_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Colab Notebooks/MCI-CN/MCI-CN/train',
                                                   target_size = (224,224),
                                                   class_mode = 'binary',
                                                   subset = 'training',
                                                   batch_size = 32)
# Out:
# Found 858 images belonging to 2 classes.

# %%
valid_dataset = valid_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Colab Notebooks/MCI-CN/MCI-CN/train',
                                                  target_size = (224,224),
                                                  class_mode = 'binary',
                                                  subset = 'validation',
                                                  batch_size = 32)
# Out:
# Found 214 images belonging to 2 classes.

# %%
test_dataset = test_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Colab Notebooks/MCI-CN/MCI-CN/test',
                                                  target_size = (224,224),
                                                  class_mode = 'binary',
                                                  batch_size = 32)
# Out:
# Found 286 images belonging to 2 classes.

# %%
base_model = DenseNet121(input_shape=(224,224,3),
                   include_top=False,
                   weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step

# %%
for layer in base_model.layers:
    layer.trainable=False

# %%
model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(tf.keras.layers.GlobalAveragePooling2D())
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('selu'))
model.add(Dropout(0.5))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('selu'))
model.add(Dropout(0.5))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('selu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('selu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('selu'))
model.add(Dense(1, activation='sigmoid'))

# %%
def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 5) 

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy',metrics=METRICS)

# %%
history=model.fit(train_dataset,
                        validation_data=valid_dataset,
                        epochs = 20,
                        verbose = 1,
                         callbacks=lr_scheduler)
# Out:
# Epoch 1/20
# 27/27 [==============================] - 606s 22s/step - loss: 0.4583 - accuracy: 0.7844 - precision: 0.8304 - recall: 0.7734 - auc: 0.8652 - f1_score: 0.8011 - val_loss: 4.4187 - val_accuracy: 0.6402 - val_precision: 0.6091 - val_recall: 1.0000 - val_auc: 0.6569 - val_f1_score: 0.7566 - lr: 0.0100
# Epoch 2/20
# 27/27 [==============================] - 15s 568ms/step - loss: 0.3370 - accuracy: 0.8625 - precision: 0.9097 - recall: 0.8378 - auc: 0.9284 - f1_score: 0.8742 - val_loss: 0.8477 - val_accuracy: 0.8318 - val_precision: 0.9667 - val_recall: 0.7250 - val_auc: 0.8925 - val_f1_score: 0.8291 - lr: 0.0063
# Epoch 3/20
# 27/27 [==============================] - 15s 561ms/step - loss: 0.2879 - accuracy: 0.8939 - precision: 0.9149 - recall: 0.8940 - auc: 0.9472 - f1_score: 0.9002 - val_loss: 0.7970 - val_accuracy: 0.8411 - val_precision: 0.9574 - val_recall: 0.7500 - val_auc: 0.8956 - val_f1_score: 0.8368 - lr: 0.0040
# Epoch 4/20
# 27/27 [==============================] - 15s 560ms/step - loss: 0.2630 - accuracy: 0.9068 - precision: 0.9349 - recall: 0.8960 - auc: 0.9528 - f1_score: 0.9146 - val_loss: 0.7639 - val_accuracy: 0.8271 - val_precision: 0.9560 - val_recall: 0.7250 - val_auc: 0.9060 - val_f1_score: 0.8112 - lr: 0.0025
# Epoch 5/20
# 27/27 [==============================] - 15s 567ms/step - loss: 0.2921 - accuracy: 0.8823 - precision: 0.9130 - recall: 0.8732 - auc: 0.9456 - f1_score: 0.8896 - val_loss: 0.6003 - val_accuracy: 0.8364 - val_precision: 0.9670 - val_recall: 0.7333 - val_auc: 0.9171 - val_f1_score: 0.8270 - lr: 0.0016
# Epoch 6/20
# 27/27 [==============================] - 18s 681ms/step - loss: 0.2084 - accuracy: 0.9172 - precision: 0.9476 - recall: 0.9023 - auc: 0.9724 - f1_score: 0.9235 - val_loss: 0.5970 - val_accuracy: 0.8224 - val_precision: 0.9659 - val_recall: 0.7083 - val_auc: 0.9186 - val_f1_score: 0.8070 - lr: 0.0010
# Epoch 7/20
# 27/27 [==============================] - 15s 561ms/step - loss: 0.2396 - accuracy: 0.9138 - precision: 0.9302 - recall: 0.9148 - auc: 0.9592 - f1_score: 0.9203 - val_loss: 0.5701 - val_accuracy: 0.8318 - val_precision: 0.9667 - val_recall: 0.7250 - val_auc: 0.9242 - val_f1_score: 0.8271 - lr: 6.3096e-04
# Epoch 8/20
# 27/27 [==============================] - 15s 570ms/step - loss: 0.2485 - accuracy: 0.9068 - precision: 0.9330 - recall: 0.8981 - auc: 0.9589 - f1_score: 0.9153 - val_loss: 0.5449 - val_accuracy: 0.8271 - val_precision: 0.9663 - val_recall: 0.7167 - val_auc: 0.9182 - val_f1_score: 0.8197 - lr: 3.9811e-04
# Epoch 9/20
# 27/27 [==============================] - 15s 565ms/step - loss: 0.2031 - accuracy: 0.9324 - precision: 0.9588 - recall: 0.9189 - auc: 0.9717 - f1_score: 0.9380 - val_loss: 0.5530 - val_accuracy: 0.8131 - val_precision: 0.9651 - val_recall: 0.6917 - val_auc: 0.9170 - val_f1_score: 0.8060 - lr: 2.5119e-04
# Epoch 10/20
# 27/27 [==============================] - 15s 564ms/step - loss: 0.2450 - accuracy: 0.9161 - precision: 0.9360 - recall: 0.9127 - auc: 0.9598 - f1_score: 0.9208 - val_loss: 0.5429 - val_accuracy: 0.8084 - val_precision: 0.9647 - val_recall: 0.6833 - val_auc: 0.9215 - val_f1_score: 0.7936 - lr: 1.5849e-04
# Epoch 11/20
# 27/27 [==============================] - 15s 558ms/step - loss: 0.2394 - accuracy: 0.9091 - precision: 0.9390 - recall: 0.8960 - auc: 0.9633 - f1_score: 0.9163 - val_loss: 0.5464 - val_accuracy: 0.8084 - val_precision: 0.9647 - val_recall: 0.6833 - val_auc: 0.9205 - val_f1_score: 0.7998 - lr: 1.0000e-04
# Epoch 12/20
# 27/27 [==============================] - 15s 556ms/step - loss: 0.2529 - accuracy: 0.9079 - precision: 0.9370 - recall: 0.8960 - auc: 0.9560 - f1_score: 0.9154 - val_loss: 0.5469 - val_accuracy: 0.8084 - val_precision: 0.9647 - val_recall: 0.6833 - val_auc: 0.9195 - val_f1_score: 0.8009 - lr: 6.3096e-05
# Epoch 13/20
# 27/27 [==============================] - 15s 562ms/step - loss: 0.2339 - accuracy: 0.9044 - precision: 0.9290 - recall: 0.8981 - auc: 0.9635 - f1_score: 0.9122 - val_loss: 0.5457 - val_accuracy: 0.8084 - val_precision: 0.9647 - val_recall: 0.6833 - val_auc: 0.9226 - val_f1_score: 0.7913 - lr: 3.9811e-05
# Epoch 14/20
# 27/27 [==============================] - 15s 558ms/step - loss: 0.2394 - accuracy: 0.9184 - precision: 0.9400 - recall: 0.9127 - auc: 0.9611 - f1_score: 0.9266 - val_loss: 0.5520 - val_accuracy: 0.8037 - val_precision: 0.9643 - val_recall: 0.6750 - val_auc: 0.9232 - val_f1_score: 0.7844 - lr: 2.5119e-05
# Epoch 15/20
# 27/27 [==============================] - 15s 563ms/step - loss: 0.2366 - accuracy: 0.9114 - precision: 0.9318 - recall: 0.9085 - auc: 0.9625 - f1_score: 0.9191 - val_loss: 0.5578 - val_accuracy: 0.8037 - val_precision: 0.9643 - val_recall: 0.6750 - val_auc: 0.9218 - val_f1_score: 0.7962 - lr: 1.5849e-05
# Epoch 16/20
# 27/27 [==============================] - 15s 557ms/step - loss: 0.2194 - accuracy: 0.9091 - precision: 0.9371 - recall: 0.8981 - auc: 0.9677 - f1_score: 0.9185 - val_loss: 0.5589 - val_accuracy: 0.8037 - val_precision: 0.9643 - val_recall: 0.6750 - val_auc: 0.9203 - val_f1_score: 0.7867 - lr: 1.0000e-05
# Epoch 17/20
# 27/27 [==============================] - 15s 552ms/step - loss: 0.2474 - accuracy: 0.9021 - precision: 0.9161 - recall: 0.9085 - auc: 0.9609 - f1_score: 0.9086 - val_loss: 0.5676 - val_accuracy: 0.8084 - val_precision: 0.9759 - val_recall: 0.6750 - val_auc: 0.9232 - val_f1_score: 0.7825 - lr: 6.3096e-06
# Epoch 18/20
# 27/27 [==============================] - 15s 558ms/step - loss: 0.2326 - accuracy: 0.9149 - precision: 0.9435 - recall: 0.9023 - auc: 0.9643 - f1_score: 0.9205 - val_loss: 0.5705 - val_accuracy: 0.8131 - val_precision: 0.9878 - val_recall: 0.6750 - val_auc: 0.9215 - val_f1_score: 0.7928 - lr: 3.9811e-06
# Epoch 19/20
# 27/27 [==============================] - 15s 556ms/step - loss: 0.2271 - accuracy: 0.9103 - precision: 0.9335 - recall: 0.9044 - auc: 0.9653 - f1_score: 0.9164 - val_loss: 0.5702 - val_accuracy: 0.8131 - val_precision: 0.9878 - val_recall: 0.6750 - val_auc: 0.9214 - val_f1_score: 0.8063 - lr: 2.5119e-06
# Epoch 20/20
# 27/27 [==============================] - 15s 559ms/step - loss: 0.2404 - accuracy: 0.8974 - precision: 0.9244 - recall: 0.8898 - auc: 0.9643 - f1_score: 0.9065 - val_loss: 0.5690 - val_accuracy: 0.8084 - val_precision: 0.9759 - val_recall: 0.6750 - val_auc: 0.9227 - val_f1_score: 0.7938 - lr: 1.5849e-06

# %%
#%% PLOTTING RESULTS (Train vs Validation FOLDER 1)

def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1,val_f1):

    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])

    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])

    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()


Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision'],
               history.history['f1_score'],history.history['val_f1_score']
              )

# %%
scores = model.evaluate(test_dataset)
# Out:
# 9/9 [==============================] - 113s 14s/step - loss: 0.1497 - accuracy: 0.9406 - precision: 0.9569 - recall: 0.9024 - auc: 0.9902 - f1_score: 0.9254

# %%
print("Accuracy = ", scores[1])
print("Precision = ", scores[2])
print("Recall = ", scores[3])
print("AUC = ", scores[4])
print("F1_score = ", scores[5])
# Out:
# Accuracy =  0.940559446811676
# Precision =  0.9568965435028076
# Recall =  0.9024389982223511
# AUC =  0.9902489185333252
# F1_score =  0.9254113435745239

# %%
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix


test_dataset.batch_size = 32  


y_true = []  # True labels
y_pred = []  # Predicted labels

# Iterate over the test dataset
for batch, labels in test_dataset:
    # Predict using the model
    predictions = model.predict(batch)

    # Convert predictions to binary (0 or 1) based on a threshold
    predictions = (predictions > 0.5).astype(int).flatten()

    # Extend the y_true and y_pred lists
    y_true.extend(labels)
    y_pred.extend(predictions)

    # Break loop if the dataset is fully iterated
    if len(y_true) >= len(test_dataset.filenames):
        break

# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sn.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
           xticklabels=['MCI', 'CN'], yticklabels=['MCI', 'CN'])

plt.xlabel('Predicted Class')
plt.ylabel('True Class')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
