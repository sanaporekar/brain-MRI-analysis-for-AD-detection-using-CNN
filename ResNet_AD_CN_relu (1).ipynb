# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import skimage.io
import os
import tqdm
import glob
import tensorflow

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import gray2rgb
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.utils import to_categorical
from keras import optimizers

from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
#from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2,

        rotation_range=5,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        #zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                  validation_split = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255
                                  )

# %%
train_dataset  = train_datagen.flow_from_directory(directory = '/content/drive/MyDrive/AD-CN/AD-CN/train',
                                                   target_size = (224,224),
                                                   class_mode = 'binary',
                                                   subset = 'training',
                                                   batch_size = 32)
# Out:
# Found 867 images belonging to 2 classes.

# %%
valid_dataset = valid_datagen.flow_from_directory(directory = '/content/drive/MyDrive/AD-CN/AD-CN/train',
                                                  target_size = (224,224),
                                                  class_mode = 'binary',
                                                  subset = 'validation',
                                                  batch_size = 32)
# Out:
# Found 216 images belonging to 2 classes.

# %%
test_dataset = test_datagen.flow_from_directory(directory = '/content/drive/MyDrive/AD-CN/AD-CN/test',
                                                  target_size = (224,224),
                                                  class_mode = 'binary',
                                                  batch_size = 32)
# Out:
# Found 323 images belonging to 2 classes.

# %%
base_model = ResNet50(input_shape=(224,224,3),
                   include_top=False,
                   weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step

# %%
# Freezing Layers

for layer in base_model.layers:
    layer.trainable=False

# %%
# Building Model

model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
# Model Summary

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  dropout (Dropout)           (None, 7, 7, 2048)        0
#
#  flatten (Flatten)           (None, 100352)            0
#
#  batch_normalization (Batch  (None, 100352)            401408
#  Normalization)
#
#  dense (Dense)               (None, 64)                6422592
#
#  batch_normalization_1 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation (Activation)     (None, 64)                0
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  batch_normalization_2 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_1 (Activation)   (None, 64)                0
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  batch_normalization_3 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_2 (Activation)   (None, 64)                0
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  batch_normalization_4 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_3 (Activation)   (None, 32)                0
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  batch_normalization_5 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_4 (Activation)   (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 30424225 (116.06 MB)
# Trainable params: 6635297 (25.31 MB)
# Non-trainable params: 23788928 (90.75 MB)
# _________________________________________________________________

# %%
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 5) # when i run it for 50 epochs

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy',metrics=METRICS)

# %%
history=model.fit(train_dataset,
                        validation_data=valid_dataset,
                        epochs = 20,
                        verbose = 1,
                         callbacks=lr_scheduler)
# Out:
# Epoch 1/20
# 28/28 [==============================] - 400s 14s/step - loss: 0.6896 - accuracy: 0.5582 - precision: 0.4908 - recall: 0.4244 - auc: 0.5874 - f1_score: 0.4329 - val_loss: 4.7067 - val_accuracy: 0.5648 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5012 - val_f1_score: 0.0000e+00 - lr: 0.0100
# Epoch 2/20
# 28/28 [==============================] - 16s 558ms/step - loss: 0.6397 - accuracy: 0.6321 - precision: 0.5873 - recall: 0.5172 - auc: 0.6809 - f1_score: 0.5260 - val_loss: 2.4013 - val_accuracy: 0.5648 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6691 - val_f1_score: 0.0000e+00 - lr: 0.0063
# Epoch 3/20
# 28/28 [==============================] - 15s 550ms/step - loss: 0.5779 - accuracy: 0.6932 - precision: 0.6398 - recall: 0.6737 - auc: 0.7598 - f1_score: 0.6266 - val_loss: 0.9713 - val_accuracy: 0.5972 - val_precision: 1.0000 - val_recall: 0.0745 - val_auc: 0.7688 - val_f1_score: 0.1189 - lr: 0.0040
# Epoch 4/20
# 28/28 [==============================] - 16s 565ms/step - loss: 0.5955 - accuracy: 0.6736 - precision: 0.6230 - recall: 0.6313 - auc: 0.7426 - f1_score: 0.5995 - val_loss: 0.6142 - val_accuracy: 0.6898 - val_precision: 0.7288 - val_recall: 0.4574 - val_auc: 0.7849 - val_f1_score: 0.5625 - lr: 0.0025
# Epoch 5/20
# 28/28 [==============================] - 16s 560ms/step - loss: 0.5789 - accuracy: 0.6828 - precision: 0.6175 - recall: 0.7109 - auc: 0.7627 - f1_score: 0.6530 - val_loss: 0.5347 - val_accuracy: 0.7130 - val_precision: 0.6600 - val_recall: 0.7021 - val_auc: 0.8045 - val_f1_score: 0.6838 - lr: 0.0016
# Epoch 6/20
# 28/28 [==============================] - 16s 556ms/step - loss: 0.5310 - accuracy: 0.7405 - precision: 0.6863 - recall: 0.7427 - auc: 0.8131 - f1_score: 0.6870 - val_loss: 0.5273 - val_accuracy: 0.7269 - val_precision: 0.6423 - val_recall: 0.8404 - val_auc: 0.8206 - val_f1_score: 0.7343 - lr: 0.0010
# Epoch 7/20
# 28/28 [==============================] - 15s 551ms/step - loss: 0.5630 - accuracy: 0.7163 - precision: 0.6594 - recall: 0.7188 - auc: 0.7769 - f1_score: 0.6769 - val_loss: 0.5387 - val_accuracy: 0.7269 - val_precision: 0.6296 - val_recall: 0.9043 - val_auc: 0.8246 - val_f1_score: 0.7373 - lr: 6.3096e-04
# Epoch 8/20
# 28/28 [==============================] - 20s 713ms/step - loss: 0.5273 - accuracy: 0.7416 - precision: 0.6861 - recall: 0.7480 - auc: 0.8071 - f1_score: 0.6905 - val_loss: 0.5468 - val_accuracy: 0.7176 - val_precision: 0.6170 - val_recall: 0.9255 - val_auc: 0.8248 - val_f1_score: 0.7325 - lr: 3.9811e-04
# Epoch 9/20
# 28/28 [==============================] - 16s 574ms/step - loss: 0.5419 - accuracy: 0.7301 - precision: 0.6706 - recall: 0.7454 - auc: 0.7874 - f1_score: 0.7085 - val_loss: 0.5527 - val_accuracy: 0.6991 - val_precision: 0.5986 - val_recall: 0.9362 - val_auc: 0.8246 - val_f1_score: 0.7287 - lr: 2.5119e-04
# Epoch 10/20
# 28/28 [==============================] - 15s 552ms/step - loss: 0.5211 - accuracy: 0.7463 - precision: 0.6874 - recall: 0.7639 - auc: 0.8119 - f1_score: 0.6915 - val_loss: 0.5528 - val_accuracy: 0.7037 - val_precision: 0.6014 - val_recall: 0.9468 - val_auc: 0.8244 - val_f1_score: 0.7271 - lr: 1.5849e-04
# Epoch 11/20
# 28/28 [==============================] - 16s 560ms/step - loss: 0.5434 - accuracy: 0.7174 - precision: 0.6549 - recall: 0.7401 - auc: 0.7916 - f1_score: 0.6698 - val_loss: 0.5509 - val_accuracy: 0.7083 - val_precision: 0.6054 - val_recall: 0.9468 - val_auc: 0.8232 - val_f1_score: 0.7345 - lr: 1.0000e-04
# Epoch 12/20
# 28/28 [==============================] - 17s 597ms/step - loss: 0.5302 - accuracy: 0.7324 - precision: 0.6755 - recall: 0.7401 - auc: 0.8084 - f1_score: 0.7006 - val_loss: 0.5475 - val_accuracy: 0.7176 - val_precision: 0.6138 - val_recall: 0.9468 - val_auc: 0.8243 - val_f1_score: 0.7422 - lr: 6.3096e-05
# Epoch 13/20
# 28/28 [==============================] - 16s 563ms/step - loss: 0.5381 - accuracy: 0.7290 - precision: 0.6723 - recall: 0.7347 - auc: 0.7968 - f1_score: 0.6957 - val_loss: 0.5464 - val_accuracy: 0.7130 - val_precision: 0.6111 - val_recall: 0.9362 - val_auc: 0.8232 - val_f1_score: 0.7274 - lr: 3.9811e-05
# Epoch 14/20
# 28/28 [==============================] - 16s 556ms/step - loss: 0.5181 - accuracy: 0.7693 - precision: 0.7185 - recall: 0.7719 - auc: 0.8314 - f1_score: 0.7278 - val_loss: 0.5436 - val_accuracy: 0.7315 - val_precision: 0.6268 - val_recall: 0.9468 - val_auc: 0.8224 - val_f1_score: 0.7541 - lr: 2.5119e-05
# Epoch 15/20
# 28/28 [==============================] - 16s 559ms/step - loss: 0.5206 - accuracy: 0.7324 - precision: 0.6698 - recall: 0.7586 - auc: 0.8174 - f1_score: 0.7025 - val_loss: 0.5404 - val_accuracy: 0.7269 - val_precision: 0.6241 - val_recall: 0.9362 - val_auc: 0.8214 - val_f1_score: 0.7488 - lr: 1.5849e-05
# Epoch 16/20
# 28/28 [==============================] - 16s 562ms/step - loss: 0.5305 - accuracy: 0.7405 - precision: 0.6735 - recall: 0.7825 - auc: 0.8080 - f1_score: 0.7266 - val_loss: 0.5375 - val_accuracy: 0.7222 - val_precision: 0.6214 - val_recall: 0.9255 - val_auc: 0.8246 - val_f1_score: 0.7274 - lr: 1.0000e-05
# Epoch 17/20
# 28/28 [==============================] - 16s 562ms/step - loss: 0.5267 - accuracy: 0.7359 - precision: 0.6779 - recall: 0.7480 - auc: 0.8115 - f1_score: 0.6843 - val_loss: 0.5356 - val_accuracy: 0.7083 - val_precision: 0.6131 - val_recall: 0.8936 - val_auc: 0.8219 - val_f1_score: 0.7271 - lr: 6.3096e-06
# Epoch 18/20
# 28/28 [==============================] - 21s 731ms/step - loss: 0.5224 - accuracy: 0.7428 - precision: 0.6860 - recall: 0.7533 - auc: 0.8187 - f1_score: 0.7225 - val_loss: 0.5348 - val_accuracy: 0.7083 - val_precision: 0.6131 - val_recall: 0.8936 - val_auc: 0.8228 - val_f1_score: 0.7130 - lr: 3.9811e-06
# Epoch 19/20
# 28/28 [==============================] - 18s 662ms/step - loss: 0.5252 - accuracy: 0.7451 - precision: 0.6921 - recall: 0.7454 - auc: 0.8093 - f1_score: 0.7074 - val_loss: 0.5333 - val_accuracy: 0.7130 - val_precision: 0.6176 - val_recall: 0.8936 - val_auc: 0.8230 - val_f1_score: 0.7319 - lr: 2.5119e-06
# Epoch 20/20
# 28/28 [==============================] - 16s 561ms/step - loss: 0.5295 - accuracy: 0.7393 - precision: 0.6819 - recall: 0.7507 - auc: 0.8096 - f1_score: 0.6848 - val_loss: 0.5299 - val_accuracy: 0.7130 - val_precision: 0.6176 - val_recall: 0.8936 - val_auc: 0.8225 - val_f1_score: 0.7222 - lr: 1.5849e-06

# %%
#%% PLOTTING RESULTS (Train vs Validation FOLDER 1)

def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1,val_f1):

    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])

    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])

    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()


Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision'],
               history.history['f1_score'],history.history['val_f1_score']
              )

# %%
scores = model.evaluate(test_dataset)
# Out:
# 11/11 [==============================] - 107s 11s/step - loss: 0.5481 - accuracy: 0.7492 - precision: 0.6881 - recall: 0.9202 - auc: 0.8285 - f1_score: 0.7641

# %%
print("Accuracy = ", scores[1])
print("Precision = ", scores[2])
print("Recall = ", scores[3])
print("AUC = ", scores[4])
print("F1_score = ", scores[5])
# Out:
# Accuracy =  0.7492260336875916
# Precision =  0.6880733966827393
# Recall =  0.9202454090118408
# AUC =  0.8285084366798401
# F1_score =  0.7641034722328186
