# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import skimage.io
import os
import tqdm
import glob
import tensorflow

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import gray2rgb
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.utils import to_categorical
from keras import optimizers

from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
import keras.backend as K

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2,

        rotation_range=5,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                  validation_split = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255
                                  )

# %%
train_dataset  = train_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Colab Notebooks/MCI_AD/train',
                                                   target_size = (224,224),
                                                   class_mode = 'binary',
                                                   subset = 'training',
                                                   batch_size = 32)
# Out:
# Found 352 images belonging to 2 classes.

# %%
valid_dataset = valid_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Colab Notebooks/MCI_AD/train',
                                                  target_size = (224,224),
                                                  class_mode = 'binary',
                                                  subset = 'validation',
                                                  batch_size = 32)
# Out:
# Found 87 images belonging to 2 classes.

# %%
test_dataset = test_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Colab Notebooks/MCI_AD/test',
                                                  target_size = (224,224),
                                                  class_mode = 'binary',
                                                  batch_size = 32)
# Out:
# Found 130 images belonging to 2 classes.

# %%
base_model = ResNet50(input_shape=(224,224,3),
                   include_top=False,
                   weights="imagenet")

# %%
# Freezing Layers

for layer in base_model.layers:
    layer.trainable=False

# %%
# Building Model

model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('selu'))
model.add(Dropout(0.5))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('selu'))
model.add(Dropout(0.5))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('selu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('selu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('selu'))
model.add(Dense(1,activation='sigmoid'))

# %%
# Model Summary

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  dropout_5 (Dropout)         (None, 7, 7, 2048)        0
#
#  flatten_1 (Flatten)         (None, 100352)            0
#
#  batch_normalization_6 (Bat  (None, 100352)            401408
#  chNormalization)
#
#  dense_6 (Dense)             (None, 64)                6422592
#
#  batch_normalization_7 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_5 (Activation)   (None, 64)                0
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  batch_normalization_8 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_6 (Activation)   (None, 64)                0
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 64)                4160
#
#  batch_normalization_9 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_7 (Activation)   (None, 64)                0
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 32)                2080
#
#  batch_normalization_10 (Ba  (None, 32)                128
#  tchNormalization)
#
#  activation_8 (Activation)   (None, 32)                0
#
#  dropout_9 (Dropout)         (None, 32)                0
#
#  dense_10 (Dense)            (None, 32)                1056
#
#  batch_normalization_11 (Ba  (None, 32)                128
#  tchNormalization)
#
#  activation_9 (Activation)   (None, 32)                0
#
#  dense_11 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 30424225 (116.06 MB)
# Trainable params: 6635297 (25.31 MB)
# Non-trainable params: 23788928 (90.75 MB)
# _________________________________________________________________

# %%
def f1_score(y_true, y_pred): 
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 5) # when i run it for 50 epochs

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy',metrics=METRICS)

# %%
history=model.fit(train_dataset,
                        validation_data=valid_dataset,
                        epochs = 20,
                        verbose = 1,
                         callbacks=lr_scheduler)
# Out:
# Epoch 1/20
# 11/11 [==============================] - 8s 702ms/step - loss: 0.5070 - accuracy: 0.7472 - precision: 0.7302 - recall: 0.7841 - auc: 0.8337 - f1_score: 0.7520 - val_loss: 0.5025 - val_accuracy: 0.7701 - val_precision: 0.7727 - val_recall: 0.7727 - val_auc: 0.8137 - val_f1_score: 0.7553 - lr: 0.0100
# Epoch 2/20
# 11/11 [==============================] - 6s 521ms/step - loss: 0.5213 - accuracy: 0.7472 - precision: 0.7430 - recall: 0.7557 - auc: 0.8206 - f1_score: 0.7448 - val_loss: 0.4788 - val_accuracy: 0.7931 - val_precision: 0.7708 - val_recall: 0.8409 - val_auc: 0.8483 - val_f1_score: 0.7833 - lr: 0.0063
# Epoch 3/20
# 11/11 [==============================] - 7s 634ms/step - loss: 0.4952 - accuracy: 0.7642 - precision: 0.7487 - recall: 0.7955 - auc: 0.8421 - f1_score: 0.7703 - val_loss: 0.5043 - val_accuracy: 0.7701 - val_precision: 0.7609 - val_recall: 0.7955 - val_auc: 0.8457 - val_f1_score: 0.7872 - lr: 0.0040
# Epoch 4/20
# 11/11 [==============================] - 6s 519ms/step - loss: 0.4936 - accuracy: 0.7614 - precision: 0.7421 - recall: 0.8011 - auc: 0.8316 - f1_score: 0.7677 - val_loss: 0.5197 - val_accuracy: 0.7586 - val_precision: 0.7674 - val_recall: 0.7500 - val_auc: 0.8634 - val_f1_score: 0.7585 - lr: 0.0025
# Epoch 5/20
# 11/11 [==============================] - 6s 520ms/step - loss: 0.4620 - accuracy: 0.7869 - precision: 0.7701 - recall: 0.8182 - auc: 0.8610 - f1_score: 0.7888 - val_loss: 0.4920 - val_accuracy: 0.7931 - val_precision: 0.7600 - val_recall: 0.8636 - val_auc: 0.8406 - val_f1_score: 0.8028 - lr: 0.0016
# Epoch 6/20
# 11/11 [==============================] - 8s 759ms/step - loss: 0.4935 - accuracy: 0.7812 - precision: 0.7592 - recall: 0.8239 - auc: 0.8368 - f1_score: 0.7840 - val_loss: 0.4677 - val_accuracy: 0.8046 - val_precision: 0.7647 - val_recall: 0.8864 - val_auc: 0.8480 - val_f1_score: 0.8241 - lr: 0.0010
# Epoch 7/20
# 11/11 [==============================] - 6s 515ms/step - loss: 0.4749 - accuracy: 0.7955 - precision: 0.7680 - recall: 0.8466 - auc: 0.8427 - f1_score: 0.8019 - val_loss: 0.4562 - val_accuracy: 0.8046 - val_precision: 0.7647 - val_recall: 0.8864 - val_auc: 0.8483 - val_f1_score: 0.7735 - lr: 6.3096e-04
# Epoch 8/20
# 11/11 [==============================] - 7s 634ms/step - loss: 0.4866 - accuracy: 0.7756 - precision: 0.7566 - recall: 0.8125 - auc: 0.8465 - f1_score: 0.7843 - val_loss: 0.4556 - val_accuracy: 0.8046 - val_precision: 0.7647 - val_recall: 0.8864 - val_auc: 0.8462 - val_f1_score: 0.8019 - lr: 3.9811e-04
# Epoch 9/20
# 11/11 [==============================] - 6s 526ms/step - loss: 0.4929 - accuracy: 0.7670 - precision: 0.7500 - recall: 0.8011 - auc: 0.8393 - f1_score: 0.7708 - val_loss: 0.4517 - val_accuracy: 0.8046 - val_precision: 0.7647 - val_recall: 0.8864 - val_auc: 0.8449 - val_f1_score: 0.8176 - lr: 2.5119e-04
# Epoch 10/20
# 11/11 [==============================] - 6s 579ms/step - loss: 0.4847 - accuracy: 0.7756 - precision: 0.7437 - recall: 0.8409 - auc: 0.8440 - f1_score: 0.7875 - val_loss: 0.4490 - val_accuracy: 0.8046 - val_precision: 0.7647 - val_recall: 0.8864 - val_auc: 0.8449 - val_f1_score: 0.8158 - lr: 1.5849e-04
# Epoch 11/20
# 11/11 [==============================] - 6s 538ms/step - loss: 0.4925 - accuracy: 0.7642 - precision: 0.7460 - recall: 0.8011 - auc: 0.8292 - f1_score: 0.7714 - val_loss: 0.4467 - val_accuracy: 0.8046 - val_precision: 0.7647 - val_recall: 0.8864 - val_auc: 0.8446 - val_f1_score: 0.8008 - lr: 1.0000e-04
# Epoch 12/20
# 11/11 [==============================] - 6s 543ms/step - loss: 0.4703 - accuracy: 0.7841 - precision: 0.7632 - recall: 0.8239 - auc: 0.8574 - f1_score: 0.7908 - val_loss: 0.4457 - val_accuracy: 0.8046 - val_precision: 0.7647 - val_recall: 0.8864 - val_auc: 0.8462 - val_f1_score: 0.8124 - lr: 6.3096e-05
# Epoch 13/20
# 11/11 [==============================] - 6s 566ms/step - loss: 0.4665 - accuracy: 0.7898 - precision: 0.7656 - recall: 0.8352 - auc: 0.8565 - f1_score: 0.7983 - val_loss: 0.4439 - val_accuracy: 0.8046 - val_precision: 0.7647 - val_recall: 0.8864 - val_auc: 0.8480 - val_f1_score: 0.8184 - lr: 3.9811e-05
# Epoch 14/20
# 11/11 [==============================] - 6s 530ms/step - loss: 0.4892 - accuracy: 0.7841 - precision: 0.7604 - recall: 0.8295 - auc: 0.8328 - f1_score: 0.7897 - val_loss: 0.4432 - val_accuracy: 0.8161 - val_precision: 0.7692 - val_recall: 0.9091 - val_auc: 0.8473 - val_f1_score: 0.8332 - lr: 2.5119e-05
# Epoch 15/20
# 11/11 [==============================] - 6s 529ms/step - loss: 0.4932 - accuracy: 0.7727 - precision: 0.7500 - recall: 0.8182 - auc: 0.8372 - f1_score: 0.7828 - val_loss: 0.4424 - val_accuracy: 0.8161 - val_precision: 0.7692 - val_recall: 0.9091 - val_auc: 0.8486 - val_f1_score: 0.8281 - lr: 1.5849e-05
# Epoch 16/20
# 11/11 [==============================] - 7s 649ms/step - loss: 0.4922 - accuracy: 0.7699 - precision: 0.7411 - recall: 0.8295 - auc: 0.8357 - f1_score: 0.7804 - val_loss: 0.4420 - val_accuracy: 0.8276 - val_precision: 0.7736 - val_recall: 0.9318 - val_auc: 0.8486 - val_f1_score: 0.8379 - lr: 1.0000e-05
# Epoch 17/20
# 11/11 [==============================] - 6s 529ms/step - loss: 0.4835 - accuracy: 0.7926 - precision: 0.7668 - recall: 0.8409 - auc: 0.8453 - f1_score: 0.7976 - val_loss: 0.4414 - val_accuracy: 0.8276 - val_precision: 0.7736 - val_recall: 0.9318 - val_auc: 0.8491 - val_f1_score: 0.8095 - lr: 6.3096e-06
# Epoch 18/20
# 11/11 [==============================] - 7s 653ms/step - loss: 0.4870 - accuracy: 0.7642 - precision: 0.7514 - recall: 0.7898 - auc: 0.8425 - f1_score: 0.7687 - val_loss: 0.4412 - val_accuracy: 0.8276 - val_precision: 0.7736 - val_recall: 0.9318 - val_auc: 0.8491 - val_f1_score: 0.8511 - lr: 3.9811e-06
# Epoch 19/20
# 11/11 [==============================] - 6s 525ms/step - loss: 0.4720 - accuracy: 0.7898 - precision: 0.7576 - recall: 0.8523 - auc: 0.8475 - f1_score: 0.7995 - val_loss: 0.4411 - val_accuracy: 0.8276 - val_precision: 0.7736 - val_recall: 0.9318 - val_auc: 0.8454 - val_f1_score: 0.8501 - lr: 2.5119e-06
# Epoch 20/20
# 11/11 [==============================] - 7s 645ms/step - loss: 0.4614 - accuracy: 0.7784 - precision: 0.7579 - recall: 0.8182 - auc: 0.8604 - f1_score: 0.7836 - val_loss: 0.4410 - val_accuracy: 0.8161 - val_precision: 0.7593 - val_recall: 0.9318 - val_auc: 0.8480 - val_f1_score: 0.8356 - lr: 1.5849e-06

# %%
#%% PLOTTING RESULTS (Train vs Validation FOLDER 1)

def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1,val_f1):

    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])

    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])

    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()


Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision'],
               history.history['f1_score'],history.history['val_f1_score']
              )

# %%
scores = model.evaluate(test_dataset)
# Out:
# 5/5 [==============================] - 1s 122ms/step - loss: 0.3522 - accuracy: 0.8692 - precision: 0.8280 - recall: 0.9872 - auc: 0.8931 - f1_score: 0.9186

# %%
print("Accuracy = ", scores[1])
print("Precision = ", scores[2])
print("Recall = ", scores[3])
print("AUC = ", scores[4])
print("F1_score = ", scores[5])
# Out:
# Accuracy =  0.8692307472229004
# Precision =  0.8279569745063782
# Recall =  0.9871794581413269
# AUC =  0.8931213617324829
# F1_score =  0.9185692667961121
