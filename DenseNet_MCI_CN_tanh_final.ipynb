# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import skimage.io
import os
import tqdm
import glob
import tensorflow

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import gray2rgb

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import DenseNet121 

from keras import optimizers

from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
import keras.backend as K
from typing import Optional

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2,

        rotation_range=5,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                  validation_split = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255
                                  )

# %%
train_dataset  = train_datagen.flow_from_directory(directory = '/content/drive/MyDrive/MCI-CN/MCI-CN/train',
                                                   target_size = (224,224),
                                                   class_mode = 'binary',
                                                   subset = 'training',
                                                   batch_size = 32)
# Out:
# Found 858 images belonging to 2 classes.

# %%
valid_dataset = valid_datagen.flow_from_directory(directory = '/content/drive/MyDrive/MCI-CN/MCI-CN/train',
                                                  target_size = (224,224),
                                                  class_mode = 'binary',
                                                  subset = 'validation',
                                                  batch_size = 32)
# Out:
# Found 214 images belonging to 2 classes.

# %%
test_dataset = test_datagen.flow_from_directory(directory = '/content/drive/MyDrive/MCI-CN/MCI-CN/test',
                                                  target_size = (224,224),
                                                  class_mode = 'binary',
                                                  batch_size = 32)
# Out:
# Found 286 images belonging to 2 classes.

# %%
base_model = DenseNet121(input_shape=(224,224,3),
                   include_top=False,
                   weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step

# %%
for layer in base_model.layers:
    layer.trainable=False

# %%
model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(tf.keras.layers.GlobalAveragePooling2D())
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(64,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('tanh'))
model.add(Dense(1, activation='sigmoid'))

# %%
def f1_score(y_true, y_pred): 
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 5) 

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy',metrics=METRICS)

# %%
history=model.fit(train_dataset,
                        validation_data=valid_dataset,
                        epochs = 20,
                        verbose = 1,
                         callbacks=lr_scheduler)
# Out:
# Epoch 1/20
# 27/27 [==============================] - 206s 7s/step - loss: 0.4339 - accuracy: 0.7937 - precision: 0.8319 - recall: 0.7921 - auc: 0.8797 - f1_score: 0.8099 - val_loss: 0.6614 - val_accuracy: 0.7991 - val_precision: 0.7984 - val_recall: 0.8583 - val_auc: 0.8786 - val_f1_score: 0.8296 - lr: 0.0100
# Epoch 2/20
# 27/27 [==============================] - 16s 576ms/step - loss: 0.3108 - accuracy: 0.8916 - precision: 0.9273 - recall: 0.8753 - auc: 0.9317 - f1_score: 0.9002 - val_loss: 0.5962 - val_accuracy: 0.8178 - val_precision: 0.8462 - val_recall: 0.8250 - val_auc: 0.8876 - val_f1_score: 0.8345 - lr: 0.0063
# Epoch 3/20
# 27/27 [==============================] - 15s 555ms/step - loss: 0.2721 - accuracy: 0.9009 - precision: 0.9459 - recall: 0.8732 - auc: 0.9476 - f1_score: 0.9078 - val_loss: 0.6482 - val_accuracy: 0.8084 - val_precision: 0.8435 - val_recall: 0.8083 - val_auc: 0.8820 - val_f1_score: 0.8209 - lr: 0.0040
# Epoch 4/20
# 27/27 [==============================] - 16s 580ms/step - loss: 0.2713 - accuracy: 0.8904 - precision: 0.9216 - recall: 0.8794 - auc: 0.9520 - f1_score: 0.8986 - val_loss: 0.5980 - val_accuracy: 0.8224 - val_precision: 0.8942 - val_recall: 0.7750 - val_auc: 0.9059 - val_f1_score: 0.8292 - lr: 0.0025
# Epoch 5/20
# 27/27 [==============================] - 15s 560ms/step - loss: 0.2593 - accuracy: 0.9079 - precision: 0.9370 - recall: 0.8960 - auc: 0.9510 - f1_score: 0.9168 - val_loss: 0.5394 - val_accuracy: 0.8364 - val_precision: 0.8972 - val_recall: 0.8000 - val_auc: 0.9188 - val_f1_score: 0.8517 - lr: 0.0016
# Epoch 6/20
# 27/27 [==============================] - 16s 604ms/step - loss: 0.2338 - accuracy: 0.9138 - precision: 0.9532 - recall: 0.8898 - auc: 0.9609 - f1_score: 0.9203 - val_loss: 0.5136 - val_accuracy: 0.8318 - val_precision: 0.9200 - val_recall: 0.7667 - val_auc: 0.9223 - val_f1_score: 0.8319 - lr: 0.0010
# Epoch 7/20
# 27/27 [==============================] - 15s 553ms/step - loss: 0.2607 - accuracy: 0.9044 - precision: 0.9346 - recall: 0.8919 - auc: 0.9543 - f1_score: 0.9099 - val_loss: 0.4893 - val_accuracy: 0.8458 - val_precision: 0.9307 - val_recall: 0.7833 - val_auc: 0.9178 - val_f1_score: 0.8485 - lr: 6.3096e-04
# Epoch 8/20
# 27/27 [==============================] - 15s 564ms/step - loss: 0.2655 - accuracy: 0.8986 - precision: 0.9246 - recall: 0.8919 - auc: 0.9552 - f1_score: 0.9089 - val_loss: 0.4898 - val_accuracy: 0.8458 - val_precision: 0.9579 - val_recall: 0.7583 - val_auc: 0.9169 - val_f1_score: 0.8440 - lr: 3.9811e-04
# Epoch 9/20
# 27/27 [==============================] - 15s 565ms/step - loss: 0.2438 - accuracy: 0.9068 - precision: 0.9349 - recall: 0.8960 - auc: 0.9601 - f1_score: 0.9152 - val_loss: 0.4938 - val_accuracy: 0.8458 - val_precision: 0.9579 - val_recall: 0.7583 - val_auc: 0.9230 - val_f1_score: 0.8427 - lr: 2.5119e-04
# Epoch 10/20
# 27/27 [==============================] - 16s 565ms/step - loss: 0.2762 - accuracy: 0.8939 - precision: 0.9239 - recall: 0.8836 - auc: 0.9510 - f1_score: 0.9024 - val_loss: 0.4971 - val_accuracy: 0.8411 - val_precision: 0.9574 - val_recall: 0.7500 - val_auc: 0.9233 - val_f1_score: 0.8371 - lr: 1.5849e-04
# Epoch 11/20
# 27/27 [==============================] - 16s 577ms/step - loss: 0.2435 - accuracy: 0.9091 - precision: 0.9390 - recall: 0.8960 - auc: 0.9588 - f1_score: 0.9166 - val_loss: 0.4991 - val_accuracy: 0.8318 - val_precision: 0.9565 - val_recall: 0.7333 - val_auc: 0.9178 - val_f1_score: 0.8188 - lr: 1.0000e-04
# Epoch 12/20
# 27/27 [==============================] - 14s 536ms/step - loss: 0.2555 - accuracy: 0.9068 - precision: 0.9312 - recall: 0.9002 - auc: 0.9563 - f1_score: 0.9140 - val_loss: 0.5019 - val_accuracy: 0.8318 - val_precision: 0.9565 - val_recall: 0.7333 - val_auc: 0.9179 - val_f1_score: 0.8184 - lr: 6.3096e-05
# Epoch 13/20
# 27/27 [==============================] - 15s 548ms/step - loss: 0.2557 - accuracy: 0.9021 - precision: 0.9287 - recall: 0.8940 - auc: 0.9540 - f1_score: 0.9097 - val_loss: 0.5033 - val_accuracy: 0.8271 - val_precision: 0.9663 - val_recall: 0.7167 - val_auc: 0.9191 - val_f1_score: 0.8129 - lr: 3.9811e-05
# Epoch 14/20
# 27/27 [==============================] - 15s 564ms/step - loss: 0.2664 - accuracy: 0.9091 - precision: 0.9371 - recall: 0.8981 - auc: 0.9490 - f1_score: 0.9174 - val_loss: 0.5066 - val_accuracy: 0.8271 - val_precision: 0.9663 - val_recall: 0.7167 - val_auc: 0.9269 - val_f1_score: 0.8182 - lr: 2.5119e-05
# Epoch 15/20
# 27/27 [==============================] - 16s 576ms/step - loss: 0.2886 - accuracy: 0.8963 - precision: 0.9242 - recall: 0.8877 - auc: 0.9402 - f1_score: 0.9057 - val_loss: 0.5054 - val_accuracy: 0.8271 - val_precision: 0.9663 - val_recall: 0.7167 - val_auc: 0.9238 - val_f1_score: 0.8195 - lr: 1.5849e-05
# Epoch 16/20
# 27/27 [==============================] - 15s 560ms/step - loss: 0.2440 - accuracy: 0.9056 - precision: 0.9274 - recall: 0.9023 - auc: 0.9599 - f1_score: 0.9144 - val_loss: 0.5057 - val_accuracy: 0.8271 - val_precision: 0.9663 - val_recall: 0.7167 - val_auc: 0.9219 - val_f1_score: 0.8181 - lr: 1.0000e-05
# Epoch 17/20
# 27/27 [==============================] - 15s 568ms/step - loss: 0.2914 - accuracy: 0.9021 - precision: 0.9251 - recall: 0.8981 - auc: 0.9388 - f1_score: 0.9100 - val_loss: 0.5094 - val_accuracy: 0.8271 - val_precision: 0.9663 - val_recall: 0.7167 - val_auc: 0.9241 - val_f1_score: 0.8129 - lr: 6.3096e-06
# Epoch 18/20
# 27/27 [==============================] - 15s 563ms/step - loss: 0.2816 - accuracy: 0.8974 - precision: 0.9244 - recall: 0.8898 - auc: 0.9479 - f1_score: 0.9060 - val_loss: 0.5132 - val_accuracy: 0.8271 - val_precision: 0.9663 - val_recall: 0.7167 - val_auc: 0.9242 - val_f1_score: 0.8143 - lr: 3.9811e-06
# Epoch 19/20
# 27/27 [==============================] - 17s 631ms/step - loss: 0.2434 - accuracy: 0.9091 - precision: 0.9371 - recall: 0.8981 - auc: 0.9619 - f1_score: 0.9182 - val_loss: 0.5171 - val_accuracy: 0.8224 - val_precision: 0.9659 - val_recall: 0.7083 - val_auc: 0.9251 - val_f1_score: 0.8137 - lr: 2.5119e-06
# Epoch 20/20
# 27/27 [==============================] - 18s 670ms/step - loss: 0.2603 - accuracy: 0.9056 - precision: 0.9386 - recall: 0.8898 - auc: 0.9528 - f1_score: 0.9123 - val_loss: 0.5174 - val_accuracy: 0.8178 - val_precision: 0.9655 - val_recall: 0.7000 - val_auc: 0.9275 - val_f1_score: 0.8064 - lr: 1.5849e-06

# %%
#%% PLOTTING RESULTS (Train vs Validation FOLDER 1)

def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1,val_f1):

    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])

    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])

    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()


Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision'],
               history.history['f1_score'],history.history['val_f1_score']
              )

# %%
scores = model.evaluate(test_dataset)
# Out:
# 9/9 [==============================] - 79s 10s/step - loss: 0.1529 - accuracy: 0.9476 - precision: 0.9500 - recall: 0.9268 - auc: 0.9881 - f1_score: 0.9359

# %%
print("Accuracy = ", scores[1])
print("Precision = ", scores[2])
print("Recall = ", scores[3])
print("AUC = ", scores[4])
print("F1_score = ", scores[5])
# Out:
# Accuracy =  0.9475524425506592
# Precision =  0.949999988079071
# Recall =  0.9268292784690857
# AUC =  0.9880542755126953
# F1_score =  0.9359427690505981

# %%
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix


test_dataset.batch_size = 32 


y_true = []  # True labels
y_pred = []  # Predicted labels

# Iterate over the test dataset
for batch, labels in test_dataset:
    # Predict using the model
    predictions = model.predict(batch)

    # Convert predictions to binary (0 or 1) based on a threshold
    predictions = (predictions > 0.5).astype(int).flatten()

    # Extend the y_true and y_pred lists
    y_true.extend(labels)
    y_pred.extend(predictions)

    # Break loop if the dataset is fully iterated
    if len(y_true) >= len(test_dataset.filenames):
        break

# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sn.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
           xticklabels=['MCI', 'CN'], yticklabels=['MCI', 'CN'])

plt.xlabel('Predicted Class')
plt.ylabel('True Class')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 2s 2s/step
